# %%
import PIL
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Using the image class

# %%
from PIL import Image
img = Image.open(r"C:\Users\khush\Pictures\1bfde3fc-5fe7-445d-8d9f-a45ee10cd6c5.jpg")

# %%
print(img.format , img.size , img.mode)
# Out:
# JPEG (853, 1280) RGB

# %%
img.show()

# %%
plt.imshow(img)

# %% [markdown]
# convert file to JPEG
